# %%
import duckdb

# Vi skal have lavet en connection til en database.
conn = duckdb.connect('elprisdata.db')

# %%
# conn.execute('''CREATE OR REPLACE TABLE taxi_data AS 
#                SELECT * FROM read_parquet('yellow_tripdata_2024-01.parquet');''')
