# %% [markdown]
# # Notebook til liiiiiiige at få leget lidt med energinet modellen

# %%
from models.energinet import Energinet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from models.energinet import Energinet
#
# File ~/source/akk/live/ts39/elpris/elpris/models/energinet.py:24
#       8     DK2 = "DK2"
#      11     """
#      12
#      13
#    (...)     20
#      21     """
# ---> 24 class Energinet(BaseModel):
#      25     url : str = "https://api.energidataservice.dk/dataset/Elspotprices"
#      26     start : datetime
#
# File ~/source/akk/live/ts39/elpris/elpris/models/energinet.py:31, in Energinet()
#      28 price_area : PriceArea
#      29 sort : str
# ---> 31 @field_serializer('start')
#      32 def serialize_from_date_time(self, from_dt : datetime) -> str:
#      33     return from_dt.strftime('%Y-%m-%d')
#      35 # Vi skal også have lavet en serializer for to_date_time
#      36 # .model_dump() vil lave vores model om til et dictionary
#
# ...

# %%
# Vi laver en instans af energinet modellen. 

Energinet : energinet_model = Energinet.create_now()

energinet_model.model_dump()
