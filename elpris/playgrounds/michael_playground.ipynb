# %%
from elpris import *

region : str = 'dk1'

tarif_ting : TaxAndFees = TaxAndFees()

nu = datetime.now()

print(nu)

tid = pd.Timestamp(datetime.now())

tarif = tarif_ting.get_nettarif(charge_time=tid)

print(tarif)
print("onkel reje")
# Out:
#   Cell In[6], line 13
#     tarif = tarif_ting.get_nettarif(charge_time=tid))
#                                                     ^
# SyntaxError: unmatched ')'
